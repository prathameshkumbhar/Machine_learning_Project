# %% [markdown]
# # Importing modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# # 1 Importing DataSet

# %%
df=pd.read_csv("C:\Users\Prathamesh\Anaconda2\diabetes-200520-125813.txt")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
from matplotlib import pyplot as plt 
import numpy as np

# %%
df.shape
# Out:
# (768, 9)

# %% [markdown]
# # 2  Checking NULL values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
x=df.mean

# %%
x
# Out:
# <bound method DataFrame.mean of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %% [markdown]
# # 3.Exploratory Data Analysis
# # i.Draw  histograms for all the columns in the dataset

# %% [markdown]
# # a.Univariate Analysis

# %% [markdown]
# # Histogram 1 (Pregnancies)

# %%
Pregnancies_list = df["Pregnancies"].tolist()
Pregnancies_list
# Out:
# [6L,
#  1L,
#  8L,
#  1L,
#  0L,
#  5L,
#  3L,
#  10L,
#  2L,
#  8L,
#  4L,
#  10L,
#  10L,
#  1L,
#  5L,
#  7L,
#  0L,
#  7L,
#  1L,
#  1L,
#  3L,
#  8L,
#  7L,
#  9L,
#  11L,
#  10L,
#  7L,
#  1L,
#  13L,
#  5L,
#  5L,
#  3L,
#  3L,
#  6L,
#  10L,
#  4L,
#  11L,
#  9L,
#  2L,
#  4L,
#  3L,
#  7L,
#  7L,
#  9L,
#  7L,
#  0L,
#  1L,
#  2L,
#  7L,
#  7L,
#  1L,
#  1L,
#  5L,
#  8L,
#  7L,
#  1L,
#  7L,
#  0L,
#  0L,
#  0L,
#  2L,
#  8L,
#  5L,
#  2L,
#  7L,
#  5L,
#  0L,
#  2L,
#  1L,
#  4L,
#  2L,
#  5L,
#  13L,
#  4L,
#  1L,
#  1L,
#  7L,
#  5L,
#  0L,
#  2L,
#  3L,
#  2L,
#  7L,
#  0L,
#  5L,
#  2L,
#  13L,
#  2L,
#  15L,
#  1L,
#  1L,
#  4L,
#  7L,
#  4L,
#  2L,
#  6L,
#  2L,
#  1L,
#  6L,
#  1L,
#  1L,
#  1L,
#  0L,
#  1L,
#  2L,
#  1L,
#  1L,
#  4L,
#  3L,
#  0L,
#  3L,
#  8L,
#  1L,
#  4L,
#  7L,
#  4L,
#  5L,
#  5L,
#  4L,
#  4L,
#  0L,
#  6L,
#  2L,
#  5L,
#  0L,
#  1L,
#  3L,
#  1L,
#  1L,
#  0L,
#  4L,
#  9L,
#  3L,
#  8L,
#  2L,
#  2L,
#  0L,
#  0L,
#  0L,
#  5L,
#  3L,
# ...

# %%
plt.hist(Pregnancies_list, bins = 5)
plt.show()

# %% [markdown]
# # Histogram 2 (Glucose)

# %%
Glucose_list = df["Glucose"].tolist()
Glucose_list
# Out:
# [148L,
#  85L,
#  183L,
#  89L,
#  137L,
#  116L,
#  78L,
#  115L,
#  197L,
#  125L,
#  110L,
#  168L,
#  139L,
#  189L,
#  166L,
#  100L,
#  118L,
#  107L,
#  103L,
#  115L,
#  126L,
#  99L,
#  196L,
#  119L,
#  143L,
#  125L,
#  147L,
#  97L,
#  145L,
#  117L,
#  109L,
#  158L,
#  88L,
#  92L,
#  122L,
#  103L,
#  138L,
#  102L,
#  90L,
#  111L,
#  180L,
#  133L,
#  106L,
#  171L,
#  159L,
#  180L,
#  146L,
#  71L,
#  103L,
#  105L,
#  103L,
#  101L,
#  88L,
#  176L,
#  150L,
#  73L,
#  187L,
#  100L,
#  146L,
#  105L,
#  84L,
#  133L,
#  44L,
#  141L,
#  114L,
#  99L,
#  109L,
#  109L,
#  95L,
#  146L,
#  100L,
#  139L,
#  126L,
#  129L,
#  79L,
#  0L,
#  62L,
#  95L,
#  131L,
#  112L,
#  113L,
#  74L,
#  83L,
#  101L,
#  137L,
#  110L,
#  106L,
#  100L,
#  136L,
#  107L,
#  80L,
#  123L,
#  81L,
#  134L,
#  142L,
#  144L,
#  92L,
#  71L,
#  93L,
#  122L,
#  163L,
#  151L,
#  125L,
#  81L,
#  85L,
#  126L,
#  96L,
#  144L,
#  83L,
#  95L,
#  171L,
#  155L,
#  89L,
#  76L,
# ...

# %%
plt.hist(Glucose_list, bins = 5)
plt.show()

# %% [markdown]
# # Histogram 3 (BloodPressure)

# %%
BloodPressure_list = df["BloodPressure"].tolist()
BloodPressure_list
# Out:
# [72L,
#  66L,
#  64L,
#  66L,
#  40L,
#  74L,
#  50L,
#  0L,
#  70L,
#  96L,
#  92L,
#  74L,
#  80L,
#  60L,
#  72L,
#  0L,
#  84L,
#  74L,
#  30L,
#  70L,
#  88L,
#  84L,
#  90L,
#  80L,
#  94L,
#  70L,
#  76L,
#  66L,
#  82L,
#  92L,
#  75L,
#  76L,
#  58L,
#  92L,
#  78L,
#  60L,
#  76L,
#  76L,
#  68L,
#  72L,
#  64L,
#  84L,
#  92L,
#  110L,
#  64L,
#  66L,
#  56L,
#  70L,
#  66L,
#  0L,
#  80L,
#  50L,
#  66L,
#  90L,
#  66L,
#  50L,
#  68L,
#  88L,
#  82L,
#  64L,
#  0L,
#  72L,
#  62L,
#  58L,
#  66L,
#  74L,
#  88L,
#  92L,
#  66L,
#  85L,
#  66L,
#  64L,
#  90L,
#  86L,
#  75L,
#  48L,
#  78L,
#  72L,
#  0L,
#  66L,
#  44L,
#  0L,
#  78L,
#  65L,
#  108L,
#  74L,
#  72L,
#  68L,
#  70L,
#  68L,
#  55L,
#  80L,
#  78L,
#  72L,
#  82L,
#  72L,
#  62L,
#  48L,
#  50L,
#  90L,
#  72L,
#  60L,
#  96L,
#  72L,
#  65L,
#  56L,
#  122L,
#  58L,
#  58L,
#  85L,
#  72L,
#  62L,
#  76L,
#  62L,
#  54L,
#  92L,
#  74L,
#  48L,
#  60L,
#  76L,
#  76L,
#  64L,
#  74L,
#  80L,
#  76L,
# ...

# %%
plt.hist(BloodPressure_list, bins = 5)
plt.show()

# %% [markdown]
# # Histogram 4 (SkinThickness)

# %%
SkinThickness_list = df["SkinThickness"].tolist()
SkinThickness_list
# Out:
# [35L,
#  29L,
#  0L,
#  23L,
#  35L,
#  0L,
#  32L,
#  0L,
#  45L,
#  0L,
#  0L,
#  0L,
#  0L,
#  23L,
#  19L,
#  0L,
#  47L,
#  0L,
#  38L,
#  30L,
#  41L,
#  0L,
#  0L,
#  35L,
#  33L,
#  26L,
#  0L,
#  15L,
#  19L,
#  0L,
#  26L,
#  36L,
#  11L,
#  0L,
#  31L,
#  33L,
#  0L,
#  37L,
#  42L,
#  47L,
#  25L,
#  0L,
#  18L,
#  24L,
#  0L,
#  39L,
#  0L,
#  27L,
#  32L,
#  0L,
#  11L,
#  15L,
#  21L,
#  34L,
#  42L,
#  10L,
#  39L,
#  60L,
#  0L,
#  41L,
#  0L,
#  0L,
#  0L,
#  34L,
#  0L,
#  27L,
#  30L,
#  0L,
#  13L,
#  27L,
#  20L,
#  35L,
#  0L,
#  20L,
#  30L,
#  20L,
#  0L,
#  33L,
#  0L,
#  22L,
#  13L,
#  0L,
#  26L,
#  28L,
#  0L,
#  29L,
#  54L,
#  25L,
#  32L,
#  19L,
#  0L,
#  15L,
#  40L,
#  0L,
#  18L,
#  27L,
#  28L,
#  18L,
#  30L,
#  51L,
#  0L,
#  0L,
#  0L,
#  18L,
#  0L,
#  29L,
#  0L,
#  28L,
#  31L,
#  25L,
#  33L,
#  26L,
#  34L,
#  0L,
#  32L,
#  0L,
#  0L,
#  0L,
#  23L,
#  15L,
#  56L,
#  39L,
#  30L,
#  0L,
#  0L,
#  42L,
#  30L,
#  36L,
#  24L,
#  0L,
# ...

# %%
plt.hist(SkinThickness_list, bins = 5)
plt.show()

# %% [markdown]
# # Histogram 5 (Insulin)

# %%
Insulin_list = df["Insulin"].tolist()
Insulin_list
# Out:
# [0L,
#  0L,
#  0L,
#  94L,
#  168L,
#  0L,
#  88L,
#  0L,
#  543L,
#  0L,
#  0L,
#  0L,
#  0L,
#  846L,
#  175L,
#  0L,
#  230L,
#  0L,
#  83L,
#  96L,
#  235L,
#  0L,
#  0L,
#  0L,
#  146L,
#  115L,
#  0L,
#  140L,
#  110L,
#  0L,
#  0L,
#  245L,
#  54L,
#  0L,
#  0L,
#  192L,
#  0L,
#  0L,
#  0L,
#  207L,
#  70L,
#  0L,
#  0L,
#  240L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  82L,
#  36L,
#  23L,
#  300L,
#  342L,
#  0L,
#  304L,
#  110L,
#  0L,
#  142L,
#  0L,
#  0L,
#  0L,
#  128L,
#  0L,
#  0L,
#  0L,
#  0L,
#  38L,
#  100L,
#  90L,
#  140L,
#  0L,
#  270L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  71L,
#  0L,
#  0L,
#  125L,
#  0L,
#  71L,
#  110L,
#  0L,
#  0L,
#  176L,
#  48L,
#  0L,
#  64L,
#  228L,
#  0L,
#  76L,
#  64L,
#  220L,
#  0L,
#  0L,
#  0L,
#  40L,
#  0L,
#  152L,
#  0L,
#  140L,
#  18L,
#  36L,
#  135L,
#  495L,
#  37L,
#  0L,
#  175L,
#  0L,
#  0L,
#  0L,
#  0L,
#  51L,
#  100L,
#  0L,
#  100L,
#  0L,
#  0L,
#  99L,
#  135L,
#  94L,
# ...

# %%
plt.hist(Insulin_list, bins = 5)
plt.show()

# %% [markdown]
# # Histogram 6 (BMI)

# %%
BMI_list = df["BMI"].tolist()
BMI_list
# Out:
# [33.6,
#  26.6,
#  23.3,
#  28.1,
#  43.1,
#  25.6,
#  31.0,
#  35.3,
#  30.5,
#  0.0,
#  37.6,
#  38.0,
#  27.1,
#  30.1,
#  25.8,
#  30.0,
#  45.8,
#  29.6,
#  43.3,
#  34.6,
#  39.3,
#  35.4,
#  39.8,
#  29.0,
#  36.6,
#  31.1,
#  39.4,
#  23.2,
#  22.2,
#  34.1,
#  36.0,
#  31.6,
#  24.8,
#  19.9,
#  27.6,
#  24.0,
#  33.2,
#  32.9,
#  38.2,
#  37.1,
#  34.0,
#  40.2,
#  22.7,
#  45.4,
#  27.4,
#  42.0,
#  29.7,
#  28.0,
#  39.1,
#  0.0,
#  19.4,
#  24.2,
#  24.4,
#  33.7,
#  34.7,
#  23.0,
#  37.7,
#  46.8,
#  40.5,
#  41.5,
#  0.0,
#  32.9,
#  25.0,
#  25.4,
#  32.8,
#  29.0,
#  32.5,
#  42.7,
#  19.6,
#  28.9,
#  32.9,
#  28.6,
#  43.4,
#  35.1,
#  32.0,
#  24.7,
#  32.6,
#  37.7,
#  43.2,
#  25.0,
#  22.4,
#  0.0,
#  29.3,
#  24.6,
#  48.8,
#  32.4,
#  36.6,
#  38.5,
#  37.1,
#  26.5,
#  19.1,
#  32.0,
#  46.7,
#  23.8,
#  24.7,
#  33.9,
#  31.6,
#  20.4,
#  28.7,
#  49.7,
#  39.0,
#  26.1,
#  22.5,
#  26.6,
#  39.6,
#  28.7,
#  22.4,
#  29.5,
#  34.3,
#  37.4,
#  33.3,
# ...

# %%
plt.hist(BMI_list, bins = 5)
plt.show()

# %% [markdown]
# # Histogram 7 (DiabetesPedigreeFunction)

# %%
DiabetesPedigreeFunction_list = df["DiabetesPedigreeFunction"].tolist()
DiabetesPedigreeFunction_list
# Out:
# [0.627,
#  0.35100000000000003,
#  0.672,
#  0.16699999999999998,
#  2.2880000000000003,
#  0.201,
#  0.248,
#  0.134,
#  0.158,
#  0.23199999999999998,
#  0.191,
#  0.537,
#  1.4409999999999998,
#  0.39799999999999996,
#  0.5870000000000001,
#  0.484,
#  0.551,
#  0.254,
#  0.183,
#  0.529,
#  0.7040000000000001,
#  0.38799999999999996,
#  0.451,
#  0.263,
#  0.254,
#  0.205,
#  0.257,
#  0.48700000000000004,
#  0.245,
#  0.337,
#  0.546,
#  0.851,
#  0.267,
#  0.188,
#  0.512,
#  0.966,
#  0.42,
#  0.665,
#  0.503,
#  1.39,
#  0.271,
#  0.696,
#  0.235,
#  0.721,
#  0.294,
#  1.893,
#  0.564,
#  0.586,
#  0.344,
#  0.305,
#  0.491,
#  0.526,
#  0.342,
#  0.467,
#  0.718,
#  0.248,
#  0.254,
#  0.9620000000000001,
#  1.781,
#  0.17300000000000001,
#  0.304,
#  0.27,
#  0.5870000000000001,
#  0.6990000000000001,
#  0.258,
#  0.203,
#  0.855,
#  0.845,
#  0.33399999999999996,
#  0.18899999999999997,
#  0.867,
#  0.41100000000000003,
#  0.583,
#  0.231,
#  0.396,
#  0.14,
#  0.391,
# ...

# %%
plt.hist(DiabetesPedigreeFunction_list, bins = 5)
plt.show()

# %% [markdown]
# # Histogram 8 (Age)

# %%
Age_list = df["Age"].tolist()
Age_list
# Out:
# [50L,
#  31L,
#  32L,
#  21L,
#  33L,
#  30L,
#  26L,
#  29L,
#  53L,
#  54L,
#  30L,
#  34L,
#  57L,
#  59L,
#  51L,
#  32L,
#  31L,
#  31L,
#  33L,
#  32L,
#  27L,
#  50L,
#  41L,
#  29L,
#  51L,
#  41L,
#  43L,
#  22L,
#  57L,
#  38L,
#  60L,
#  28L,
#  22L,
#  28L,
#  45L,
#  33L,
#  35L,
#  46L,
#  27L,
#  56L,
#  26L,
#  37L,
#  48L,
#  54L,
#  40L,
#  25L,
#  29L,
#  22L,
#  31L,
#  24L,
#  22L,
#  26L,
#  30L,
#  58L,
#  42L,
#  21L,
#  41L,
#  31L,
#  44L,
#  22L,
#  21L,
#  39L,
#  36L,
#  24L,
#  42L,
#  32L,
#  38L,
#  54L,
#  25L,
#  27L,
#  28L,
#  26L,
#  42L,
#  23L,
#  22L,
#  22L,
#  41L,
#  27L,
#  26L,
#  24L,
#  22L,
#  22L,
#  36L,
#  22L,
#  37L,
#  27L,
#  45L,
#  26L,
#  43L,
#  24L,
#  21L,
#  34L,
#  42L,
#  60L,
#  21L,
#  40L,
#  24L,
#  22L,
#  23L,
#  31L,
#  33L,
#  22L,
#  21L,
#  24L,
#  27L,
#  21L,
#  27L,
#  37L,
#  25L,
#  24L,
#  24L,
#  46L,
#  23L,
#  25L,
#  39L,
#  61L,
#  38L,
#  25L,
#  22L,
#  21L,
#  25L,
#  24L,
#  23L,
#  69L,
#  23L,
# ...

# %%
plt.hist(Age_list, bins = 5)
plt.show()

# %% [markdown]
# # Histogram 9 (Outcome)

# %%
Outcome_list = df["Outcome"].tolist()
Outcome_list
# Out:
# [1L,
#  0L,
#  1L,
#  0L,
#  1L,
#  0L,
#  1L,
#  0L,
#  1L,
#  1L,
#  0L,
#  1L,
#  0L,
#  1L,
#  1L,
#  1L,
#  1L,
#  1L,
#  0L,
#  1L,
#  0L,
#  0L,
#  1L,
#  1L,
#  1L,
#  1L,
#  1L,
#  0L,
#  0L,
#  0L,
#  0L,
#  1L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  1L,
#  1L,
#  1L,
#  0L,
#  0L,
#  0L,
#  1L,
#  0L,
#  1L,
#  0L,
#  0L,
#  1L,
#  0L,
#  0L,
#  0L,
#  0L,
#  1L,
#  0L,
#  0L,
#  1L,
#  0L,
#  0L,
#  0L,
#  0L,
#  1L,
#  0L,
#  0L,
#  1L,
#  0L,
#  1L,
#  0L,
#  0L,
#  0L,
#  1L,
#  0L,
#  1L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  1L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  1L,
#  0L,
#  0L,
#  0L,
#  1L,
#  0L,
#  0L,
#  0L,
#  0L,
#  1L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  1L,
#  1L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  1L,
#  1L,
#  1L,
#  0L,
#  0L,
#  1L,
#  1L,
#  1L,
#  0L,
#  0L,
#  0L,
#  1L,
#  0L,
#  0L,
#  0L,
#  1L,
#  1L,
#  0L,
#  0L,
#  1L,
#  1L,
#  1L,
#  1L,
#  1L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
#  0L,
# ...

# %%
plt.hist(Outcome_list, bins = 5)
plt.show()

# %% [markdown]
# # b.Bivariate analysis
# # i.Draw a minimum of 5 scatter plots

# %% [markdown]
# # Scatter plot 1

# %%
import matplotlib.pyplot as plt
plt.scatter("Pregnancies","Glucose")
plt.show()

# %% [markdown]
# # Scatter plot 2

# %%
import matplotlib.pyplot as plt
plt.scatter("BMI","Age")
plt.show()

# %% [markdown]
# # Scatter plot 3

# %%
import matplotlib.pyplot as plt
plt.scatter("BloodPressure","Insulin")
plt.show()

# %% [markdown]
# # Scatter plot 4

# %%
import matplotlib.pyplot as plt
plt.scatter("DiabetesPedigreeFunction","SkinThickness")
plt.show()

# %% [markdown]
# # Scatter plot 5

# %%
import matplotlib.pyplot as plt
plt.scatter("DiabetesPedigreeFunction","BloodPressure")
plt.show()

# %% [markdown]
# # 4.Modelling

# %% [markdown]
# # a.Split the dataset using “train-test-split” function.

# %%
# demonstrate that the train-test split procedure is repeatable
from sklearn.datasets import make_blobs

# create dataset
X, y = make_blobs(n_samples=100)
from sklearn.model_selection import train_test_split

# split into train test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# ((67L, 2L), (33L, 2L), (67L,), (33L,))

# %%
# split into train test sets
X_train, y_train,X_test, y_test = train_test_split(X, y, train_size=0.66)
# Out:
# C:\Users\Prathamesh\Anaconda2\lib\site-packages\sklearn\model_selection\_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %% [markdown]
# # b.Apply KNN classification on “Outcome” column of the dataset. Select the appropriate features

# %%
from sklearn import neighbors, datasets
def kneighbors_graph(self):
    self.X_train = self.X_train.values[:10,] #trimming down the data to only 10 entries
    df= neighbors.kneighbors_graph(self.X_train, 4, 'Outcome')
    #plt.spy(df)
    plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
